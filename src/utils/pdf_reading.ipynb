# %%
import os
import pickle

# %%
# !pip install grobid2json

# %%
# !python3 -m spacy download en_core_web_sm

# %%
import scipdf

# %%
article_dict = scipdf.parse_pdf_to_dict('2501.17148v2.pdf')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/TCS Research/IRIS/venv/lib/python3.9/site-packages/urllib3/connection.py:158, in HTTPConnection._new_conn(self)
#     157 try:
# --> 158     conn = connection.create_connection(
#     159         (self._dns_host, self.port), self.timeout, **extra_kw)
#     161 except SocketTimeout:
#
# File ~/TCS Research/IRIS/venv/lib/python3.9/site-packages/urllib3/util/connection.py:80, in create_connection(address, timeout, source_address, socket_options)
#      79 if err is not None:
# ---> 80     raise err
#      82 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/TCS Research/IRIS/venv/lib/python3.9/site-packages/urllib3/util/connection.py:70, in create_connection(address, timeout, source_address, socket_options)
#      69     sock.bind(source_address)
# ---> 70 sock.connect(sa)
#      71 return sock
#
# ...

# %%
article_dict

# %%
article_dict = scipdf.parse_pdf_to_dict('https://www.biorxiv.org/content/biorxiv/early/2018/11/20/463760.full.pdf', as_list=False)

# %%
xml = scipdf.parse_pdf('example_data/futoma2017improved.pdf', soup=True) # option to parse full XML from GROBID
